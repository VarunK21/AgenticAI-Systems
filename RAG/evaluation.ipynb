# %%
import numpy as np
import pandas as pd

# %%
evaluation=pd.read_csv("/workspaces/AgenticAI-Systems/RAG/Document/AI_Response_Evaluation_-_Full_20_Questions.csv")
evaluation
# Out:
#                                              Question  \
# 0   ما هو الأساس القانوني الذي استند إليه الاستئنا...
# 1   ما هو الدفع الرئيسي الذي تمسّك به مكتبنا في أو...
# 2   ما هي دفوع الخصم ضد طلباتنا كما وردت في مذكرتي...
# 3   هل تضمنت مذكرات الدفاع المقدمة من مكتبنا أي اع...
# 4   هل أشار أي طرف إلى وجود خلل في تكييف الوقائع م...
# 5   كيف تعامل كل من الخصم ومكتبنا مع مسألة قوة الأ...
# 6   ما هي المستندات التي اعتبرها الخصم غير متعلقة ...
# 7   هل أكد مكتبنا على صحة المستندات المقدمة منه؟ و...
# 8   هل أشار أي من الطرفين إلى مستندات أو عقود مرفق...
# 9   هل ورد في المستندات أي طعن في توقيع أو صحة مست...
# 10  هل تقدم أي من الطرفين بطلب إحالة الدعوى إلى خب...
# 11  ما هي الملاحظات التي وردت حول مدى التزام المحك...
# 12  هل تقدم الخصم أو مكتبنا بدفوع تتعلق بعدم القبو...
# 13  ما الطلب الاحتياطي الذي ورد في مذكرة الخصم الأ...
# 14  هل تم تحديد مواعيد أو جداول زمنية لتنفيذ الالت...
# 15  ما النتيجة التي يسعى إليها مكتبنا من خلال المذ...
# ...

# %%
for i in range(len(evaluation)):
    print(evaluation["Question"].values[i])
    print(evaluation["Evaluation"].values[i])
# Out:
# ما هو الأساس القانوني الذي استند إليه الاستئناف ضد الحكم الابتدائي؟
# ✔️ صحيح
# ما هو الدفع الرئيسي الذي تمسّك به مكتبنا في أول مذكرة دفاع؟
# ❌ خطأ
# ما هي دفوع الخصم ضد طلباتنا كما وردت في مذكرتي 18-6-2019 و19-9-2019؟
# ✔️ صحيح
# هل تضمنت مذكرات الدفاع المقدمة من مكتبنا أي اعتراضات على دفوع الخصم المتعلقة بالعلاقة التعاقدية؟
# ❌ خطأ
# هل أشار أي طرف إلى وجود خلل في تكييف الوقائع من قبل المحكمة الابتدائية؟
# ❌ خطأ
# كيف تعامل كل من الخصم ومكتبنا مع مسألة قوة الأدلة المقدّمة؟
# ❌ خطأ
# ما هي المستندات التي اعتبرها الخصم غير متعلقة بالطلب أو غير كافية لإثبات الحق؟
# ✔️ صحيح
# هل أكد مكتبنا على صحة المستندات المقدمة منه؟ وما الحجة المستخدمة؟
# ❌ خطأ
# هل أشار أي من الطرفين إلى مستندات أو عقود مرفقة ضمن المراسلات؟
# ✔️ صحيح
# هل ورد في المستندات أي طعن في توقيع أو صحة مستند معين؟
# ✔️ صحيح
# هل تقدم أي من الطرفين بطلب إحالة الدعوى إلى خبير قضائي؟
# ✔️ صحيح
# ما هي الملاحظات التي وردت حول مدى التزام المحكمة بالإجراءات الشكلية؟
# ❌ خطأ
# ...
